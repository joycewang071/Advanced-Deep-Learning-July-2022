# %% [markdown]
# # U-Net segmentation example
# ### Advanced Deep Learning 2022
# This notebook was originally written by Mathias Perslev. It has been changed slightly by Christian Igel and subsequently slightly updated [Stefan Sommer](mailto:sommer@di.ku.dk).
#
# The U-Net is based on code written by Annika Brundyn and Akshay Kulkarni distributed as part of [*PyTorch Lightning Bolts*](https://pytorch-lightning.readthedocs.io/) under the  [Apache 2.0 license](https://www.apache.org/licenses/LICENSE-2.0.txt).
#
# We consider the data described in:
#
# Bram van Ginneken, Mikkel B. Stegmann, Marco Loog. [Segmentation of anatomical structures in chest radiographs using supervised methods: a comparative study on a public database](https://doi.org/10.1016/j.media.2005.02.002). *Medical Image Analysis* 10(1): 19-40, 2006

# %% [markdown]
# ## Installs
#
# If some packages are missing:

# %%
pip install -q pytorch_lightning lightning-bolts
# Out:
#      |████████████████████████████████| 584 kB 5.3 MB/s
#      |████████████████████████████████| 316 kB 47.4 MB/s
#      |████████████████████████████████| 409 kB 54.5 MB/s
#      |████████████████████████████████| 136 kB 46.9 MB/s
#      |████████████████████████████████| 596 kB 41.9 MB/s
#      |████████████████████████████████| 1.1 MB 32.2 MB/s
#      |████████████████████████████████| 94 kB 2.5 MB/s
#      |████████████████████████████████| 271 kB 45.1 MB/s
#      |████████████████████████████████| 144 kB 50.8 MB/s

# %% [markdown]
# ## Imports

# %%
import os
import matplotlib.pyplot as plt
import numpy as np

import torch
from torch import nn as nn
from torch.nn import functional as F
from torchvision.datasets.utils import download_url

import torchmetrics

from pprint import pformat
from skimage.transform import resize
#from sklearn.metrics import f1_score
from pathlib import Path
from glob import glob
from matplotlib.pyplot import imread
from collections import defaultdict

# %% [markdown]
# ## Mount Google drive when using Google Colab

# %%
try:
    from google.colab import drive
    drive.mount('/content/gdrive/')
    os.chdir('gdrive/MyDrive/ADL2022')
except:
    print('Google drive not mounted')
# Out:
# Mounted at /content/gdrive/
# Google drive not mounted

# %% [markdown]
# ## Test for GPU support

# %%
# GPU support?
gpu = torch.cuda.is_available()
device = torch.device("cuda:0" if gpu else "cpu")
print("device:", device)
# Out:
# device: cpu

# %% [markdown]
# ## U-Net
# Import the U-Net.

# %%
from pl_bolts.models.vision import UNet

# %% [markdown]
# ## Database

# %% [markdown]
# Load database with chest X-rays with lung segmentations.

# %%
data_root='./datasets'
data_npz='lung_field_dataset.npz'
data_fn = os.path.join(data_root, "lung_field_dataset.npz")
force_download = False

if (not os.path.exists(data_fn)) or force_download:
  download_url("https://sid.erda.dk/share_redirect/gCTc6o3KAh", data_root, data_npz)
else:
  print('Using existing', data_fn)
# Out:
# Downloading https://sid.erda.dk/share_redirect/gCTc6o3KAh to ./datasets/lung_field_dataset.npz
#   0%|          | 0/80938446 [00:00<?, ?it/s]

# %%
def plot_image_with_segmentation(image, segmentation, ax=None):
    """
    Plots an image with overlayed segmentation mask
    
    Returns: plt.fig and ax objects
    """
    if ax is None:
        fig = plt.figure(figsize=(8, 8))
        ax = fig.add_subplot(111)
        ax.axis("off")
    
    ax.imshow(image.squeeze(), cmap="gray")
    mask = np.ma.masked_where(segmentation == 0, segmentation)
    ax.imshow(mask.squeeze(), cmap="Set1", alpha=0.5)
    return plt.gcf(), ax


def load_npz_dataset(path, keys=('x_train', 'y_train', 'x_val', 'y_val', 'x_test', 'y_test')):
    archive = np.load(path)
    return [archive.get(key) for key in keys]

# %%
# Load train/val/test data
x_train, y_train, x_val, y_val, x_test, y_test = load_npz_dataset(data_fn)
# Bring images into PyTorch format
x_train = np.moveaxis(x_train, 3, 1)
y_train = np.moveaxis(y_train, 3, 1)
x_val = np.moveaxis(x_val, 3, 1)
y_val = np.moveaxis(y_val, 3, 1)
x_test = np.moveaxis(x_test, 3, 1)
y_test = np.moveaxis(y_test, 3, 1)

print("x train:", x_train.shape)
print("y train:", y_train.shape)
print("x val: ", x_val.shape)
print("y val: ", y_val.shape)
print("x test:", x_test.shape)
print("y test:", y_test.shape)

# Plot an example
fig, ax = plot_image_with_segmentation(x_train[0], y_train[0])
plt.show()
# Out:
# x train: (112, 1, 256, 256)
# y train: (112, 1, 256, 256)
# x val:  (12, 1, 256, 256)
# y val:  (12, 1, 256, 256)
# x test: (123, 1, 256, 256)
# y test: (123, 1, 256, 256)

# %% [markdown]
# ### Init torch dataloaders

# %%
def as_torch_dataset(x_arr, y_arr):
    """
    Takes two numpy arrays of data points and labels (x_arr and y_arr, respectively) and
    returns a torch TensorDataset object.
    
    Returns: torch.utils.data.TensorDataset
    """
    dataset = torch.utils.data.TensorDataset(
        torch.FloatTensor(x_arr), 
        torch.LongTensor(y_arr)
    )
    return dataset

# Init torch datasets
train_dataset = as_torch_dataset(x_train, y_train.squeeze(1))  # remove dummy channel dim
val_dataset = as_torch_dataset(x_val, y_val.squeeze(1))
test_dataset = as_torch_dataset(x_test, y_test.squeeze(1))

# Init dataloaders
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=16, shuffle=True)
val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=16, shuffle=False)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=1, shuffle=False)

# %% [markdown]
# ### Function for evaluating a model on a data loader

# %%
def evaluate_model(model, data_loader, metrics_dict, reduction=True, device=device):
    """
    Evaluate a model 'model' on all batches of a torch DataLoader 'data_loader'.
    On each batch, compute all metric functions stored in dictionary 'metrics_dict'.
    
    Returns: dict of metric_name: (list of batch-wise metrics if reduction == False, else single scalar)
    """
    
    # defaultdict(list) returns a dictionary-like object with default_factory list. 
    # When a new key is encountered, an entry is automatically created of type default_factory. 
    metrics = defaultdict(list)
    with torch.no_grad():
        for batch_x, batch_y in data_loader:
            # Predict on batch
            batch_x = batch_x.to(device)
            batch_y = batch_y.to(device)
            logits = model(batch_x)
            
            # Compute all metrics
            for metric_name, metric_func in metrics_dict.items():
                value = metric_func(logits.cpu(), batch_y.cpu()).item() #.cpu().numpy()
                metrics[metric_name].append(value)
    
    if reduction == True:
        # Return mean values
        return {key: np.mean(value) for key, value in metrics.items()}
    else:
        return metrics

# %% [markdown]
# ## Main trainig loop function(s)
#
# We want to track the F1 score during training. This generates some additional code.

# %%
def run_one_epoch(model, loss, optimizer, train_loader, val_loader, n_epochs, metrics_dict, device=device):
    """
    Run 1 epoch of training
    Changes to model parameters and optimizer occour internally (state updates)
    Returns:
        two dictionaries, training and a validation metrics
    """
    train_losses = []
    for i, (batch_x, batch_y) in enumerate(train_loader):
        # Zero out stored gradients for all parameters
        batch_x = batch_x.to(device)
        batch_y = batch_y.to(device)
        optimizer.zero_grad()
        
        print(f"   -- Batch {i+1}/{len(train_loader)}", end=" / ")
        # Predict on batch
        logits = model(batch_x)
        
        # Compute loss function
        loss_tensor = loss(logits, batch_y)
        loss_scalar = loss_tensor.detach().cpu().numpy()
        train_losses.append(loss_scalar)
        print("Loss: ", loss_scalar)
        
        # Backprop and step
        loss_tensor.backward()
        optimizer.step()
        
    # Run validation
    print("   Validation running...")
    val_metrics = evaluate_model(
        model=model, 
        data_loader=val_loader,
        metrics_dict=metrics_dict
    )
    # Return loss and metrics as dicts
    return {"loss": np.mean(train_losses)}, val_metrics


def merge_list_of_dicts(list_of_dicts):
    """
    Takes a list of dictionaries and merges them into a single dictionary pointing to lists
    
    E.g. [{"loss": 5}, {"loss": 3}, {"loss": -2, "F1": 0.5}] --> {"loss": [5, 3, -2], "F1": [0.5]}
    
    Returns: dict
    """
    merged = defaultdict(list)
    for dict_ in list_of_dicts:
        for value, key in dict_.items():
            merged[value].append(key)
    return merged


def training_loop(model, loss, optimizer, train_loader, val_loader, n_epochs, init_epoch=None, metrics_dict=None, save_path=None):
    """
    Run training of a model given a loss function, optimizer and a set of training and validation data.
    Supports computing additional metrics on the validation set (only) via the metrics_dict param.
    Specify save_path to store the model at each epoch.
    
    Returns: 
        Two lists of metric dictionaries for each epoch for training and validation, specifically
    """
    train_history, val_history = [], []
    
    metrics_with_loss = {"loss": loss}
    if metrics_dict is not None:
        metrics_with_loss.update(metrics_dict)
    
    if init_epoch == None:
        init_epoch = 0
    try:
        for i in range(init_epoch, n_epochs):
            print(f"Epoch {i+1}/{n_epochs}")
            train_metrics, val_metrics = run_one_epoch(
                model=model, 
                loss=loss, 
                optimizer=optimizer, 
                train_loader=train_loader, 
                val_loader=val_loader, 
                n_epochs=n_epochs,
                metrics_dict=metrics_with_loss
            )
            print("   Mean epoch metrics:")
            print(f"   Training:   {pformat(train_metrics)}")
            print(f"   Validation: {pformat(val_metrics)}")
            train_history.append(train_metrics), val_history.append(val_metrics)
            
            if save_path:
                save_path_epoch = f"epoch_{i+1}_{save_path}"
                print(f"   Saving to: {save_path_epoch}")
                save_model(model, save_path_epoch, optimizer)
    except KeyboardInterrupt:
        print("Training stopped.")
        pass
    
    # Merge list of training and validation dicts into single dicts    
    return merge_list_of_dicts(train_history), merge_list_of_dicts(val_history)

# %% [markdown]
# ## Function for plotting training/validation histories

# %%
def plot_histories(train_history=None, val_history=None, label="Loss"):
    """
    Takes a list of training and/or validation metrics and plots them
    Returns: plt.figure and ax objects
    """
    if not train_history and not val_history:
        raise ValueError("Must specify at least one of 'train_histories' and 'val_histories'")
    fig = plt.figure(figsize=(5, 3))
    ax = fig.add_subplot(111)
    
    epochs = np.arange(len(train_history or val_history))
    if train_history:
        ax.plot(epochs, train_history, label="Training", color="black")
    if val_history:
        ax.plot(epochs, val_history, label="Validation", color="darkred")
    
    ax.set_xlabel("Epoch")
    ax.set_ylabel(label)
    ax.legend(loc=0)
    
    return fig, ax

# %% [markdown]
# ## Functions for saving and loading model and optimizer state

# %%
def save_model(model, path, optimizer=None):
    """
    Saves the state_dict of a torch model and optional optimizer to 'path'
    Returns: None
    """
    state = {"model": model.state_dict()}
    if optimizer is not None:
        state["optimizer"] = optimizer.state_dict()
    torch.save(state, path)


def load_model(model, path, optimizer=None):
    """
    Loads the state_dict of a torch model and optional optimizer from 'path'
    Returns: None
    """
    state = torch.load(path)
    model.load_state_dict(state["model"])
    if optimizer is not None:
        optimizer.load_state_dict(state["optimizer"])

# %% [markdown]
# ## Init U-Net model and optimizer

# %%
# Init U-Net model
model = UNet(
    num_classes=2, 
    input_channels=1, 
    num_layers=4, 
    features_start=16,
)

model.to(device)

# Define optimizer
optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)

# %% [markdown]
# ## Continue training?

# %%
# Specify integer, starting at 1
init_epoch = None
if init_epoch != None:
    load_model(model, f"epoch_{init_epoch}_model.ckpt", optimizer)

# %% [markdown]
# ## Run training

# %%
# Define loss and metrics
loss = torch.nn.CrossEntropyLoss(reduction="mean")
metrics = {"f1": torchmetrics.classification.F1Score(num_classes=2, average="macro", mdmc_average="samplewise")}

# Run training
train_history, val_history = training_loop(
    model=model,
    loss=loss, 
    optimizer=optimizer, 
    train_loader=train_loader, 
    val_loader=val_loader,
    init_epoch=init_epoch,
    n_epochs=100,
    metrics_dict=metrics,
    save_path="model.ckpt"
)
# Out:
# Epoch 1/100
#    -- Batch 1/7 / Loss:  0.684877
#    -- Batch 2/7 / Loss:  0.6771701
#    -- Batch 3/7 / Loss:  0.66306686
#    -- Batch 4/7 / Loss:  0.6531952
#    -- Batch 5/7 / Loss:  0.6505122
#    -- Batch 6/7 / Loss:  0.6331915
#    -- Batch 7/7 / Loss:  0.6310307
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.6561491}
#    Validation: {'f1': 0.7355155944824219, 'loss': 0.620640218257904}
#    Saving to: epoch_1_model.ckpt
# Epoch 2/100
#    -- Batch 1/7 / Loss:  0.62198615
#    -- Batch 2/7 / Loss:  0.6129162
#    -- Batch 3/7 / Loss:  0.60921353
#    -- Batch 4/7 / Loss:  0.5979679
#    -- Batch 5/7 / Loss:  0.5925427
#    -- Batch 6/7 / Loss:  0.5878768
#    -- Batch 7/7 / Loss:  0.58070284
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.600458}
#    Validation: {'f1': 0.8134670257568359, 'loss': 0.5746183395385742}
#    Saving to: epoch_2_model.ckpt
# Epoch 3/100
#    -- Batch 1/7 / Loss:  0.57371324
#    -- Batch 2/7 / Loss:  0.5714947
#    -- Batch 3/7 / Loss:  0.5660539
#    -- Batch 4/7 / Loss:  0.560126
#    -- Batch 5/7 / Loss:  0.55020463
#    -- Batch 6/7 / Loss:  0.54404604
#    -- Batch 7/7 / Loss:  0.5416486
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.55818385}
#    Validation: {'f1': 0.8429497480392456, 'loss': 0.5353070497512817}
#    Saving to: epoch_3_model.ckpt
# Epoch 4/100
#    -- Batch 1/7 / Loss:  0.54138845
#    -- Batch 2/7 / Loss:  0.52965945
#    -- Batch 3/7 / Loss:  0.5217229
#    -- Batch 4/7 / Loss:  0.5195999
#    -- Batch 5/7 / Loss:  0.51534855
#    -- Batch 6/7 / Loss:  0.51044685
#    -- Batch 7/7 / Loss:  0.5015929
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.5199656}
#    Validation: {'f1': 0.8733483552932739, 'loss': 0.49869129061698914}
#    Saving to: epoch_4_model.ckpt
# Epoch 5/100
#    -- Batch 1/7 / Loss:  0.49928105
#    -- Batch 2/7 / Loss:  0.49171385
#    -- Batch 3/7 / Loss:  0.48760515
#    -- Batch 4/7 / Loss:  0.48809376
#    -- Batch 5/7 / Loss:  0.47331992
#    -- Batch 6/7 / Loss:  0.47289678
#    -- Batch 7/7 / Loss:  0.4729388
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.48369274}
#    Validation: {'f1': 0.9035298824310303, 'loss': 0.46352288126945496}
#    Saving to: epoch_5_model.ckpt
# Epoch 6/100
#    -- Batch 1/7 / Loss:  0.46486306
#    -- Batch 2/7 / Loss:  0.45583495
#    -- Batch 3/7 / Loss:  0.4564946
#    -- Batch 4/7 / Loss:  0.44539875
#    -- Batch 5/7 / Loss:  0.44842878
#    -- Batch 6/7 / Loss:  0.44379902
#    -- Batch 7/7 / Loss:  0.44305664
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.45112512}
#    Validation: {'f1': 0.9215341806411743, 'loss': 0.4355604648590088}
#    Saving to: epoch_6_model.ckpt
# Epoch 7/100
#    -- Batch 1/7 / Loss:  0.4368
#    -- Batch 2/7 / Loss:  0.43887568
#    -- Batch 3/7 / Loss:  0.4288203
#    -- Batch 4/7 / Loss:  0.42626494
#    -- Batch 5/7 / Loss:  0.4226058
#    -- Batch 6/7 / Loss:  0.42067444
#    -- Batch 7/7 / Loss:  0.41895518
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.4275709}
#    Validation: {'f1': 0.9331690073013306, 'loss': 0.4159866273403168}
#    Saving to: epoch_7_model.ckpt
# Epoch 8/100
#    -- Batch 1/7 / Loss:  0.4152597
#    -- Batch 2/7 / Loss:  0.4142691
#    -- Batch 3/7 / Loss:  0.4137028
#    -- Batch 4/7 / Loss:  0.40683827
#    -- Batch 5/7 / Loss:  0.404185
#    -- Batch 6/7 / Loss:  0.40562376
#    -- Batch 7/7 / Loss:  0.4060417
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.40941715}
#    Validation: {'f1': 0.9406358003616333, 'loss': 0.4001455008983612}
#    Saving to: epoch_8_model.ckpt
# Epoch 9/100
#    -- Batch 1/7 / Loss:  0.40018094
#    -- Batch 2/7 / Loss:  0.39830887
#    -- Batch 3/7 / Loss:  0.3988356
#    -- Batch 4/7 / Loss:  0.39026895
#    -- Batch 5/7 / Loss:  0.39018342
#    -- Batch 6/7 / Loss:  0.39025387
#    -- Batch 7/7 / Loss:  0.39523342
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.39475217}
#    Validation: {'f1': 0.9480083584785461, 'loss': 0.38725197315216064}
#    Saving to: epoch_9_model.ckpt
# Epoch 10/100
#    -- Batch 1/7 / Loss:  0.38894948
#    -- Batch 2/7 / Loss:  0.38475308
#    -- Batch 3/7 / Loss:  0.38759196
#    -- Batch 4/7 / Loss:  0.38133782
#    -- Batch 5/7 / Loss:  0.379359
#    -- Batch 6/7 / Loss:  0.37682328
#    -- Batch 7/7 / Loss:  0.37548596
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.3820429}
#    Validation: {'f1': 0.950139045715332, 'loss': 0.3756697475910187}
#    Saving to: epoch_10_model.ckpt
# Epoch 11/100
#    -- Batch 1/7 / Loss:  0.37433055
#    -- Batch 2/7 / Loss:  0.3773314
#    -- Batch 3/7 / Loss:  0.37265578
#    -- Batch 4/7 / Loss:  0.37219617
#    -- Batch 5/7 / Loss:  0.3682816
#    -- Batch 6/7 / Loss:  0.3665987
#    -- Batch 7/7 / Loss:  0.3660706
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.3710664}
#    Validation: {'f1': 0.9579813480377197, 'loss': 0.3659496605396271}
#    Saving to: epoch_11_model.ckpt
# Epoch 12/100
#    -- Batch 1/7 / Loss:  0.36425665
#    -- Batch 2/7 / Loss:  0.3638333
#    -- Batch 3/7 / Loss:  0.3655205
#    -- Batch 4/7 / Loss:  0.35815236
#    -- Batch 5/7 / Loss:  0.35626322
#    -- Batch 6/7 / Loss:  0.359381
#    -- Batch 7/7 / Loss:  0.35938406
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.36097017}
#    Validation: {'f1': 0.9605386853218079, 'loss': 0.35633325576782227}
#    Saving to: epoch_12_model.ckpt
# Epoch 13/100
#    -- Batch 1/7 / Loss:  0.35736957
#    -- Batch 2/7 / Loss:  0.35600358
#    -- Batch 3/7 / Loss:  0.3541303
#    -- Batch 4/7 / Loss:  0.35161853
#    -- Batch 5/7 / Loss:  0.3485116
#    -- Batch 6/7 / Loss:  0.34913713
#    -- Batch 7/7 / Loss:  0.34624255
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.35185903}
#    Validation: {'f1': 0.9627237319946289, 'loss': 0.3486996591091156}
#    Saving to: epoch_13_model.ckpt
# Epoch 14/100
#    -- Batch 1/7 / Loss:  0.34766647
#    -- Batch 2/7 / Loss:  0.3488025
#    -- Batch 3/7 / Loss:  0.34368348
#    -- Batch 4/7 / Loss:  0.34599534
#    -- Batch 5/7 / Loss:  0.34211174
#    -- Batch 6/7 / Loss:  0.34077957
#    -- Batch 7/7 / Loss:  0.3400142
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.34415048}
#    Validation: {'f1': 0.9657258987426758, 'loss': 0.34292110800743103}
#    Saving to: epoch_14_model.ckpt
# Epoch 15/100
#    -- Batch 1/7 / Loss:  0.34217653
#    -- Batch 2/7 / Loss:  0.3358146
#    -- Batch 3/7 / Loss:  0.33635494
#    -- Batch 4/7 / Loss:  0.34212214
#    -- Batch 5/7 / Loss:  0.33696842
#    -- Batch 6/7 / Loss:  0.3342966
#    -- Batch 7/7 / Loss:  0.33613032
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.33769482}
#    Validation: {'f1': 0.9679461717605591, 'loss': 0.33546149730682373}
#    Saving to: epoch_15_model.ckpt
# Epoch 16/100
#    -- Batch 1/7 / Loss:  0.33202374
#    -- Batch 2/7 / Loss:  0.33251658
#    -- Batch 3/7 / Loss:  0.330906
#    -- Batch 4/7 / Loss:  0.33042258
#    -- Batch 5/7 / Loss:  0.32856354
#    -- Batch 6/7 / Loss:  0.33265972
#    -- Batch 7/7 / Loss:  0.33012092
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.33103043}
#    Validation: {'f1': 0.9688159227371216, 'loss': 0.329290509223938}
#    Saving to: epoch_16_model.ckpt
# Epoch 17/100
#    -- Batch 1/7 / Loss:  0.32586768
#    -- Batch 2/7 / Loss:  0.32589272
#    -- Batch 3/7 / Loss:  0.32304868
#    -- Batch 4/7 / Loss:  0.3234108
#    -- Batch 5/7 / Loss:  0.327225
#    -- Batch 6/7 / Loss:  0.32580587
#    -- Batch 7/7 / Loss:  0.3222776
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.32478976}
#    Validation: {'f1': 0.9704209566116333, 'loss': 0.32501542568206787}
#    Saving to: epoch_17_model.ckpt
# Epoch 18/100
#    -- Batch 1/7 / Loss:  0.32108423
#    -- Batch 2/7 / Loss:  0.3255445
#    -- Batch 3/7 / Loss:  0.31931046
#    -- Batch 4/7 / Loss:  0.32548812
#    -- Batch 5/7 / Loss:  0.316803
#    -- Batch 6/7 / Loss:  0.31758526
#    -- Batch 7/7 / Loss:  0.31624863
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.32029486}
#    Validation: {'f1': 0.9709293842315674, 'loss': 0.32013973593711853}
#    Saving to: epoch_18_model.ckpt
# Epoch 19/100
#    -- Batch 1/7 / Loss:  0.31676257
#    -- Batch 2/7 / Loss:  0.31506708
#    -- Batch 3/7 / Loss:  0.31195253
#    -- Batch 4/7 / Loss:  0.3157272
#    -- Batch 5/7 / Loss:  0.3132277
#    -- Batch 6/7 / Loss:  0.31281835
#    -- Batch 7/7 / Loss:  0.31702477
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.3146543}
#    Validation: {'f1': 0.9715979099273682, 'loss': 0.31537505984306335}
#    Saving to: epoch_19_model.ckpt
# Epoch 20/100
#    -- Batch 1/7 / Loss:  0.3115455
#    -- Batch 2/7 / Loss:  0.31118146
#    -- Batch 3/7 / Loss:  0.3109813
#    -- Batch 4/7 / Loss:  0.3073566
#    -- Batch 5/7 / Loss:  0.3088001
#    -- Batch 6/7 / Loss:  0.31396505
#    -- Batch 7/7 / Loss:  0.30754802
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.31019685}
#    Validation: {'f1': 0.9717270135879517, 'loss': 0.3108377754688263}
#    Saving to: epoch_20_model.ckpt
# Epoch 21/100
#    -- Batch 1/7 / Loss:  0.30808082
#    -- Batch 2/7 / Loss:  0.30528545
#    -- Batch 3/7 / Loss:  0.30507895
#    -- Batch 4/7 / Loss:  0.3083171
#    -- Batch 5/7 / Loss:  0.30545127
#    -- Batch 6/7 / Loss:  0.30205235
#    -- Batch 7/7 / Loss:  0.30567622
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.30570602}
#    Validation: {'f1': 0.9723202586174011, 'loss': 0.3056824505329132}
#    Saving to: epoch_21_model.ckpt
# Epoch 22/100
#    -- Batch 1/7 / Loss:  0.30673042
#    -- Batch 2/7 / Loss:  0.30039024
#    -- Batch 3/7 / Loss:  0.30099663
#    -- Batch 4/7 / Loss:  0.30505428
#    -- Batch 5/7 / Loss:  0.29832923
#    -- Batch 6/7 / Loss:  0.2991411
#    -- Batch 7/7 / Loss:  0.29688665
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.30107552}
#    Validation: {'f1': 0.9723992347717285, 'loss': 0.30236902832984924}
#    Saving to: epoch_22_model.ckpt
# Epoch 23/100
#    -- Batch 1/7 / Loss:  0.29575315
#    -- Batch 2/7 / Loss:  0.30032676
#    -- Batch 3/7 / Loss:  0.30412823
#    -- Batch 4/7 / Loss:  0.2952308
#    -- Batch 5/7 / Loss:  0.29512647
#    -- Batch 6/7 / Loss:  0.2942066
#    -- Batch 7/7 / Loss:  0.29733863
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.29744437}
#    Validation: {'f1': 0.9729731678962708, 'loss': 0.29883602261543274}
#    Saving to: epoch_23_model.ckpt
# Epoch 24/100
#    -- Batch 1/7 / Loss:  0.29596063
#    -- Batch 2/7 / Loss:  0.29321197
#    -- Batch 3/7 / Loss:  0.29432005
#    -- Batch 4/7 / Loss:  0.29639402
#    -- Batch 5/7 / Loss:  0.2933019
#    -- Batch 6/7 / Loss:  0.2886406
#    -- Batch 7/7 / Loss:  0.28828695
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.29287377}
#    Validation: {'f1': 0.9732347726821899, 'loss': 0.2951558232307434}
#    Saving to: epoch_24_model.ckpt
# Epoch 25/100
#    -- Batch 1/7 / Loss:  0.29088426
#    -- Batch 2/7 / Loss:  0.29005206
#    -- Batch 3/7 / Loss:  0.2893333
#    -- Batch 4/7 / Loss:  0.289183
#    -- Batch 5/7 / Loss:  0.28509286
#    -- Batch 6/7 / Loss:  0.28814733
#    -- Batch 7/7 / Loss:  0.28767762
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.28862435}
#    Validation: {'f1': 0.972875714302063, 'loss': 0.29094937443733215}
#    Saving to: epoch_25_model.ckpt
# Epoch 26/100
#    -- Batch 1/7 / Loss:  0.28818297
#    -- Batch 2/7 / Loss:  0.28484634
#    -- Batch 3/7 / Loss:  0.28496882
#    -- Batch 4/7 / Loss:  0.28805506
#    -- Batch 5/7 / Loss:  0.28263557
#    -- Batch 6/7 / Loss:  0.28473365
#    -- Batch 7/7 / Loss:  0.28231388
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.2851052}
#    Validation: {'f1': 0.9730921983718872, 'loss': 0.28749069571495056}
#    Saving to: epoch_26_model.ckpt
# Epoch 27/100
#    -- Batch 1/7 / Loss:  0.28250515
#    -- Batch 2/7 / Loss:  0.29200193
#    -- Batch 3/7 / Loss:  0.28004554
#    -- Batch 4/7 / Loss:  0.28035435
#    -- Batch 5/7 / Loss:  0.27839077
#    -- Batch 6/7 / Loss:  0.28119633
#    -- Batch 7/7 / Loss:  0.27808857
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.28179753}
#    Validation: {'f1': 0.973870038986206, 'loss': 0.28381168842315674}
#    Saving to: epoch_27_model.ckpt
# Epoch 28/100
#    -- Batch 1/7 / Loss:  0.27456287
#    -- Batch 2/7 / Loss:  0.28179866
#    -- Batch 3/7 / Loss:  0.2821758
#    -- Batch 4/7 / Loss:  0.27648363
#    -- Batch 5/7 / Loss:  0.27608365
#    -- Batch 6/7 / Loss:  0.27665156
#    -- Batch 7/7 / Loss:  0.27628276
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.2777199}
#    Validation: {'f1': 0.9739765524864197, 'loss': 0.2807573676109314}
#    Saving to: epoch_28_model.ckpt
# Epoch 29/100
#    -- Batch 1/7 / Loss:  0.27412277
#    -- Batch 2/7 / Loss:  0.2755917
#    -- Batch 3/7 / Loss:  0.27647102
#    -- Batch 4/7 / Loss:  0.2739101
#    -- Batch 5/7 / Loss:  0.27393168
#    -- Batch 6/7 / Loss:  0.27050346
#    -- Batch 7/7 / Loss:  0.27238476
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.27384508}
#    Validation: {'f1': 0.9733870029449463, 'loss': 0.2781992554664612}
#    Saving to: epoch_29_model.ckpt
# Epoch 30/100
#    -- Batch 1/7 / Loss:  0.27034608
#    -- Batch 2/7 / Loss:  0.27077088
#    -- Batch 3/7 / Loss:  0.27193815
#    -- Batch 4/7 / Loss:  0.2689236
#    -- Batch 5/7 / Loss:  0.27036735
#    -- Batch 6/7 / Loss:  0.27219427
#    -- Batch 7/7 / Loss:  0.2696574
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.27059966}
#    Validation: {'f1': 0.9744292497634888, 'loss': 0.2745385468006134}
#    Saving to: epoch_30_model.ckpt
# Epoch 31/100
#    -- Batch 1/7 / Loss:  0.26821375
#    -- Batch 2/7 / Loss:  0.26963875
#    -- Batch 3/7 / Loss:  0.26830855
#    -- Batch 4/7 / Loss:  0.26529786
#    -- Batch 5/7 / Loss:  0.2679512
#    -- Batch 6/7 / Loss:  0.2701379
#    -- Batch 7/7 / Loss:  0.26325187
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.26754284}
#    Validation: {'f1': 0.9732720851898193, 'loss': 0.27237117290496826}
#    Saving to: epoch_31_model.ckpt
# Epoch 32/100
#    -- Batch 1/7 / Loss:  0.26606464
#    -- Batch 2/7 / Loss:  0.26833984
#    -- Batch 3/7 / Loss:  0.2638365
#    -- Batch 4/7 / Loss:  0.26150328
#    -- Batch 5/7 / Loss:  0.26337588
#    -- Batch 6/7 / Loss:  0.26020774
#    -- Batch 7/7 / Loss:  0.26168442
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.2635732}
#    Validation: {'f1': 0.9743872880935669, 'loss': 0.2685199975967407}
#    Saving to: epoch_32_model.ckpt
# Epoch 33/100
#    -- Batch 1/7 / Loss:  0.2609499
#    -- Batch 2/7 / Loss:  0.26357174
#    -- Batch 3/7 / Loss:  0.2596743
#    -- Batch 4/7 / Loss:  0.2592379
#    -- Batch 5/7 / Loss:  0.2614035
#    -- Batch 6/7 / Loss:  0.25991258
#    -- Batch 7/7 / Loss:  0.25896195
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.2605303}
#    Validation: {'f1': 0.9744448661804199, 'loss': 0.2652064859867096}
#    Saving to: epoch_33_model.ckpt
# Epoch 34/100
#    -- Batch 1/7 / Loss:  0.2566661
#    -- Batch 2/7 / Loss:  0.25680637
#    -- Batch 3/7 / Loss:  0.25967628
#    -- Batch 4/7 / Loss:  0.25701973
#    -- Batch 5/7 / Loss:  0.25613922
#    -- Batch 6/7 / Loss:  0.25814044
#    -- Batch 7/7 / Loss:  0.2580163
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.2574949}
#    Validation: {'f1': 0.9745969772338867, 'loss': 0.26309934258461}
#    Saving to: epoch_34_model.ckpt
# Epoch 35/100
#    -- Batch 1/7 / Loss:  0.25506842
#    -- Batch 2/7 / Loss:  0.2528183
#    -- Batch 3/7 / Loss:  0.2570064
#    -- Batch 4/7 / Loss:  0.25558254
#    -- Batch 5/7 / Loss:  0.25327805
#    -- Batch 6/7 / Loss:  0.25401193
#    -- Batch 7/7 / Loss:  0.25182688
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.2542275}
#    Validation: {'f1': 0.9745082855224609, 'loss': 0.2605687975883484}
#    Saving to: epoch_35_model.ckpt
# Epoch 36/100
#    -- Batch 1/7 / Loss:  0.25019434
#    -- Batch 2/7 / Loss:  0.24867657
#    -- Batch 3/7 / Loss:  0.25199628
#    -- Batch 4/7 / Loss:  0.25116688
#    -- Batch 5/7 / Loss:  0.2512699
#    -- Batch 6/7 / Loss:  0.25586617
#    -- Batch 7/7 / Loss:  0.25178954
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.25156567}
#    Validation: {'f1': 0.9741098880767822, 'loss': 0.258713036775589}
#    Saving to: epoch_36_model.ckpt
# Epoch 37/100
#    -- Batch 1/7 / Loss:  0.25118414
#    -- Batch 2/7 / Loss:  0.24827172
#    -- Batch 3/7 / Loss:  0.2483655
#    -- Batch 4/7 / Loss:  0.2499216
#    -- Batch 5/7 / Loss:  0.25088626
#    -- Batch 6/7 / Loss:  0.24743062
#    -- Batch 7/7 / Loss:  0.2504842
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.24950631}
#    Validation: {'f1': 0.9723819494247437, 'loss': 0.25766298174858093}
#    Saving to: epoch_37_model.ckpt
# Epoch 38/100
#    -- Batch 1/7 / Loss:  0.2487941
#    -- Batch 2/7 / Loss:  0.2463347
#    -- Batch 3/7 / Loss:  0.24691266
#    -- Batch 4/7 / Loss:  0.24329916
#    -- Batch 5/7 / Loss:  0.24415864
#    -- Batch 6/7 / Loss:  0.24875641
#    -- Batch 7/7 / Loss:  0.24622576
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.24635448}
#    Validation: {'f1': 0.9750311374664307, 'loss': 0.2519046664237976}
#    Saving to: epoch_38_model.ckpt
# Epoch 39/100
#    -- Batch 1/7 / Loss:  0.24408619
#    -- Batch 2/7 / Loss:  0.24216333
#    -- Batch 3/7 / Loss:  0.24389473
#    -- Batch 4/7 / Loss:  0.24335873
#    -- Batch 5/7 / Loss:  0.24409172
#    -- Batch 6/7 / Loss:  0.24596527
#    -- Batch 7/7 / Loss:  0.23922235
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.24325463}
#    Validation: {'f1': 0.9746391773223877, 'loss': 0.24895012378692627}
#    Saving to: epoch_39_model.ckpt
# Epoch 40/100
#    -- Batch 1/7 / Loss:  0.23883305
#    -- Batch 2/7 / Loss:  0.24043098
#    -- Batch 3/7 / Loss:  0.24317251
#    -- Batch 4/7 / Loss:  0.24760494
#    -- Batch 5/7 / Loss:  0.23890644
#    -- Batch 6/7 / Loss:  0.23995504
#    -- Batch 7/7 / Loss:  0.24184892
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.24153599}
#    Validation: {'f1': 0.9749425649642944, 'loss': 0.2468164712190628}
#    Saving to: epoch_40_model.ckpt
# Epoch 41/100
#    -- Batch 1/7 / Loss:  0.23871523
#    -- Batch 2/7 / Loss:  0.23553047
#    -- Batch 3/7 / Loss:  0.23928948
#    -- Batch 4/7 / Loss:  0.23660578
#    -- Batch 5/7 / Loss:  0.24528044
#    -- Batch 6/7 / Loss:  0.23680674
#    -- Batch 7/7 / Loss:  0.23644616
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.23838206}
#    Validation: {'f1': 0.9732154607772827, 'loss': 0.24731725454330444}
#    Saving to: epoch_41_model.ckpt
# Epoch 42/100
#    -- Batch 1/7 / Loss:  0.23704669
#    -- Batch 2/7 / Loss:  0.23515803
#    -- Batch 3/7 / Loss:  0.23973891
#    -- Batch 4/7 / Loss:  0.23407225
#    -- Batch 5/7 / Loss:  0.23190932
#    -- Batch 6/7 / Loss:  0.232538
#    -- Batch 7/7 / Loss:  0.23587787
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.23519158}
#    Validation: {'f1': 0.975379228591919, 'loss': 0.24131987988948822}
#    Saving to: epoch_42_model.ckpt
# Epoch 43/100
#    -- Batch 1/7 / Loss:  0.23299222
#    -- Batch 2/7 / Loss:  0.23170058
#    -- Batch 3/7 / Loss:  0.23308246
#    -- Batch 4/7 / Loss:  0.23159018
#    -- Batch 5/7 / Loss:  0.23140247
#    -- Batch 6/7 / Loss:  0.2334034
#    -- Batch 7/7 / Loss:  0.23170805
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.23226848}
#    Validation: {'f1': 0.975193977355957, 'loss': 0.23909308016300201}
#    Saving to: epoch_43_model.ckpt
# Epoch 44/100
#    -- Batch 1/7 / Loss:  0.22959262
#    -- Batch 2/7 / Loss:  0.22802122
#    -- Batch 3/7 / Loss:  0.23349997
#    -- Batch 4/7 / Loss:  0.23346905
#    -- Batch 5/7 / Loss:  0.22793636
#    -- Batch 6/7 / Loss:  0.2303788
#    -- Batch 7/7 / Loss:  0.22820096
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.230157}
#    Validation: {'f1': 0.9751491546630859, 'loss': 0.23736990988254547}
#    Saving to: epoch_44_model.ckpt
# Epoch 45/100
#    -- Batch 1/7 / Loss:  0.22665851
#    -- Batch 2/7 / Loss:  0.23008025
#    -- Batch 3/7 / Loss:  0.22764389
#    -- Batch 4/7 / Loss:  0.22626972
#    -- Batch 5/7 / Loss:  0.22512238
#    -- Batch 6/7 / Loss:  0.22799924
#    -- Batch 7/7 / Loss:  0.22765884
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.22734754}
#    Validation: {'f1': 0.9747228622436523, 'loss': 0.23599369823932648}
#    Saving to: epoch_45_model.ckpt
# Epoch 46/100
#    -- Batch 1/7 / Loss:  0.22714868
#    -- Batch 2/7 / Loss:  0.2246211
#    -- Batch 3/7 / Loss:  0.22677897
#    -- Batch 4/7 / Loss:  0.22438815
#    -- Batch 5/7 / Loss:  0.22465007
#    -- Batch 6/7 / Loss:  0.22192873
#    -- Batch 7/7 / Loss:  0.22245277
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.22456692}
#    Validation: {'f1': 0.9748013019561768, 'loss': 0.23267574608325958}
#    Saving to: epoch_46_model.ckpt
# Epoch 47/100
#    -- Batch 1/7 / Loss:  0.22568808
#    -- Batch 2/7 / Loss:  0.2230228
#    -- Batch 3/7 / Loss:  0.22485949
#    -- Batch 4/7 / Loss:  0.22003861
#    -- Batch 5/7 / Loss:  0.22254585
#    -- Batch 6/7 / Loss:  0.22092287
#    -- Batch 7/7 / Loss:  0.2187675
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.22226359}
#    Validation: {'f1': 0.97523033618927, 'loss': 0.23026245832443237}
#    Saving to: epoch_47_model.ckpt
# Epoch 48/100
#    -- Batch 1/7 / Loss:  0.21699947
#    -- Batch 2/7 / Loss:  0.22192545
#    -- Batch 3/7 / Loss:  0.21849847
#    -- Batch 4/7 / Loss:  0.21920994
#    -- Batch 5/7 / Loss:  0.2212987
#    -- Batch 6/7 / Loss:  0.21917287
#    -- Batch 7/7 / Loss:  0.21945038
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.21950789}
#    Validation: {'f1': 0.974394679069519, 'loss': 0.23002010583877563}
#    Saving to: epoch_48_model.ckpt
# Epoch 49/100
#    -- Batch 1/7 / Loss:  0.2174689
#    -- Batch 2/7 / Loss:  0.21793827
#    -- Batch 3/7 / Loss:  0.21763709
#    -- Batch 4/7 / Loss:  0.21478419
#    -- Batch 5/7 / Loss:  0.21986996
#    -- Batch 6/7 / Loss:  0.21535087
#    -- Batch 7/7 / Loss:  0.21982306
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.21755317}
#    Validation: {'f1': 0.9753893613815308, 'loss': 0.22640050947666168}
#    Saving to: epoch_49_model.ckpt
# Epoch 50/100
#    -- Batch 1/7 / Loss:  0.21521516
#    -- Batch 2/7 / Loss:  0.21420747
#    -- Batch 3/7 / Loss:  0.21545075
#    -- Batch 4/7 / Loss:  0.21753517
#    -- Batch 5/7 / Loss:  0.2135767
#    -- Batch 6/7 / Loss:  0.21364972
#    -- Batch 7/7 / Loss:  0.21360682
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.21474883}
#    Validation: {'f1': 0.9756007194519043, 'loss': 0.2238243967294693}
#    Saving to: epoch_50_model.ckpt
# Epoch 51/100
#    -- Batch 1/7 / Loss:  0.21240813
#    -- Batch 2/7 / Loss:  0.21103995
#    -- Batch 3/7 / Loss:  0.2099364
#    -- Batch 4/7 / Loss:  0.2149462
#    -- Batch 5/7 / Loss:  0.21491139
#    -- Batch 6/7 / Loss:  0.21333887
#    -- Batch 7/7 / Loss:  0.21259499
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.21273942}
#    Validation: {'f1': 0.9745821952819824, 'loss': 0.22340483963489532}
#    Saving to: epoch_51_model.ckpt
# Epoch 52/100
#    -- Batch 1/7 / Loss:  0.2134084
#    -- Batch 2/7 / Loss:  0.20982026
#    -- Batch 3/7 / Loss:  0.2075756
#    -- Batch 4/7 / Loss:  0.21374652
#    -- Batch 5/7 / Loss:  0.2122531
#    -- Batch 6/7 / Loss:  0.21429142
#    -- Batch 7/7 / Loss:  0.20704308
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.21116261}
#    Validation: {'f1': 0.9746307730674744, 'loss': 0.2215278595685959}
#    Saving to: epoch_52_model.ckpt
# Epoch 53/100
#    -- Batch 1/7 / Loss:  0.2118722
#    -- Batch 2/7 / Loss:  0.21032332
#    -- Batch 3/7 / Loss:  0.20576955
#    -- Batch 4/7 / Loss:  0.21218047
#    -- Batch 5/7 / Loss:  0.20557927
#    -- Batch 6/7 / Loss:  0.20838654
#    -- Batch 7/7 / Loss:  0.20643787
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.20864989}
#    Validation: {'f1': 0.975166916847229, 'loss': 0.21811707317829132}
#    Saving to: epoch_53_model.ckpt
# Epoch 54/100
#    -- Batch 1/7 / Loss:  0.20833763
#    -- Batch 2/7 / Loss:  0.20492537
#    -- Batch 3/7 / Loss:  0.21133281
#    -- Batch 4/7 / Loss:  0.20491071
#    -- Batch 5/7 / Loss:  0.20556775
#    -- Batch 6/7 / Loss:  0.20573322
#    -- Batch 7/7 / Loss:  0.20357265
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.20634}
#    Validation: {'f1': 0.9744725823402405, 'loss': 0.2165214568376541}
#    Saving to: epoch_54_model.ckpt
# Epoch 55/100
#    -- Batch 1/7 / Loss:  0.20799214
#    -- Batch 2/7 / Loss:  0.20280617
#    -- Batch 3/7 / Loss:  0.20507221
#    -- Batch 4/7 / Loss:  0.20276938
#    -- Batch 5/7 / Loss:  0.20324136
#    -- Batch 6/7 / Loss:  0.20366678
#    -- Batch 7/7 / Loss:  0.20189083
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.20391986}
#    Validation: {'f1': 0.9749511480331421, 'loss': 0.21398745477199554}
#    Saving to: epoch_55_model.ckpt
# Epoch 56/100
#    -- Batch 1/7 / Loss:  0.20321862
#    -- Batch 2/7 / Loss:  0.20978624
#    -- Batch 3/7 / Loss:  0.20150651
#    -- Batch 4/7 / Loss:  0.20490873
#    -- Batch 5/7 / Loss:  0.20366411
#    -- Batch 6/7 / Loss:  0.19995949
#    -- Batch 7/7 / Loss:  0.19760597
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.20294996}
#    Validation: {'f1': 0.9735820889472961, 'loss': 0.21365298330783844}
#    Saving to: epoch_56_model.ckpt
# Epoch 57/100
#    -- Batch 1/7 / Loss:  0.20170942
#    -- Batch 2/7 / Loss:  0.20243114
#    -- Batch 3/7 / Loss:  0.20069814
#    -- Batch 4/7 / Loss:  0.19929163
#    -- Batch 5/7 / Loss:  0.1992592
#    -- Batch 6/7 / Loss:  0.1985158
#    -- Batch 7/7 / Loss:  0.20493497
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.20097719}
#    Validation: {'f1': 0.9763920307159424, 'loss': 0.20967383682727814}
#    Saving to: epoch_57_model.ckpt
# Epoch 58/100
#    -- Batch 1/7 / Loss:  0.20001495
#    -- Batch 2/7 / Loss:  0.19586357
#    -- Batch 3/7 / Loss:  0.19547257
#    -- Batch 4/7 / Loss:  0.20115146
#    -- Batch 5/7 / Loss:  0.1951908
#    -- Batch 6/7 / Loss:  0.20260607
#    -- Batch 7/7 / Loss:  0.20171419
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.19885908}
#    Validation: {'f1': 0.97222900390625, 'loss': 0.2133427858352661}
#    Saving to: epoch_58_model.ckpt
# Epoch 59/100
#    -- Batch 1/7 / Loss:  0.20262691
#    -- Batch 2/7 / Loss:  0.19772407
#    -- Batch 3/7 / Loss:  0.20177382
#    -- Batch 4/7 / Loss:  0.19262692
#    -- Batch 5/7 / Loss:  0.19373901
#    -- Batch 6/7 / Loss:  0.19705528
#    -- Batch 7/7 / Loss:  0.19300015
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.19693518}
#    Validation: {'f1': 0.9753726720809937, 'loss': 0.2061479538679123}
#    Saving to: epoch_59_model.ckpt
# Epoch 60/100
#    -- Batch 1/7 / Loss:  0.19182691
#    -- Batch 2/7 / Loss:  0.19754796
#    -- Batch 3/7 / Loss:  0.1934003
#    -- Batch 4/7 / Loss:  0.1964321
#    -- Batch 5/7 / Loss:  0.19239914
#    -- Batch 6/7 / Loss:  0.19333729
#    -- Batch 7/7 / Loss:  0.19440228
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.19419228}
#    Validation: {'f1': 0.9761039018630981, 'loss': 0.20383960008621216}
#    Saving to: epoch_60_model.ckpt
# Epoch 61/100
#    -- Batch 1/7 / Loss:  0.18983792
#    -- Batch 2/7 / Loss:  0.19457762
#    -- Batch 3/7 / Loss:  0.19544439
#    -- Batch 4/7 / Loss:  0.19438425
#    -- Batch 5/7 / Loss:  0.18953341
#    -- Batch 6/7 / Loss:  0.18995829
#    -- Batch 7/7 / Loss:  0.19099115
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.19210386}
#    Validation: {'f1': 0.9757524728775024, 'loss': 0.20294839143753052}
#    Saving to: epoch_61_model.ckpt
# Epoch 62/100
#    -- Batch 1/7 / Loss:  0.19209188
#    -- Batch 2/7 / Loss:  0.19031465
#    -- Batch 3/7 / Loss:  0.18740453
#    -- Batch 4/7 / Loss:  0.1901349
#    -- Batch 5/7 / Loss:  0.18895382
#    -- Batch 6/7 / Loss:  0.19231343
#    -- Batch 7/7 / Loss:  0.1891
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.19004475}
#    Validation: {'f1': 0.9754257798194885, 'loss': 0.20231328904628754}
#    Saving to: epoch_62_model.ckpt
# Epoch 63/100
#    -- Batch 1/7 / Loss:  0.19314706
#    -- Batch 2/7 / Loss:  0.1897367
#    -- Batch 3/7 / Loss:  0.18673928
#    -- Batch 4/7 / Loss:  0.18660823
#    -- Batch 5/7 / Loss:  0.18790211
#    -- Batch 6/7 / Loss:  0.19229472
#    -- Batch 7/7 / Loss:  0.18655434
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.18899749}
#    Validation: {'f1': 0.976116955280304, 'loss': 0.19894838333129883}
#    Saving to: epoch_63_model.ckpt
# Epoch 64/100
#    -- Batch 1/7 / Loss:  0.18545894
#    -- Batch 2/7 / Loss:  0.18730402
#    -- Batch 3/7 / Loss:  0.18779914
#    -- Batch 4/7 / Loss:  0.18580326
#    -- Batch 5/7 / Loss:  0.18777277
#    -- Batch 6/7 / Loss:  0.1845909
#    -- Batch 7/7 / Loss:  0.18353719
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.18603805}
#    Validation: {'f1': 0.9762534499168396, 'loss': 0.1971890926361084}
#    Saving to: epoch_64_model.ckpt
# Epoch 65/100
#    -- Batch 1/7 / Loss:  0.18389145
#    -- Batch 2/7 / Loss:  0.18210669
#    -- Batch 3/7 / Loss:  0.18633322
#    -- Batch 4/7 / Loss:  0.18810874
#    -- Batch 5/7 / Loss:  0.182727
#    -- Batch 6/7 / Loss:  0.1827578
#    -- Batch 7/7 / Loss:  0.18486969
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.18439922}
#    Validation: {'f1': 0.9759685397148132, 'loss': 0.1960417628288269}
#    Saving to: epoch_65_model.ckpt
# Epoch 66/100
#    -- Batch 1/7 / Loss:  0.18598156
#    -- Batch 2/7 / Loss:  0.18312816
#    -- Batch 3/7 / Loss:  0.18034202
#    -- Batch 4/7 / Loss:  0.18031543
#    -- Batch 5/7 / Loss:  0.17997359
#    -- Batch 6/7 / Loss:  0.18309847
#    -- Batch 7/7 / Loss:  0.18055856
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.18191397}
#    Validation: {'f1': 0.9761907458305359, 'loss': 0.1938590556383133}
#    Saving to: epoch_66_model.ckpt
# Epoch 67/100
#    -- Batch 1/7 / Loss:  0.18081288
#    -- Batch 2/7 / Loss:  0.17972134
#    -- Batch 3/7 / Loss:  0.1795128
#    -- Batch 4/7 / Loss:  0.17991552
#    -- Batch 5/7 / Loss:  0.1809742
#    -- Batch 6/7 / Loss:  0.18312982
#    -- Batch 7/7 / Loss:  0.1775558
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.18023178}
#    Validation: {'f1': 0.9764851331710815, 'loss': 0.19210785627365112}
#    Saving to: epoch_67_model.ckpt
# Epoch 68/100
#    -- Batch 1/7 / Loss:  0.17832293
#    -- Batch 2/7 / Loss:  0.1774207
#    -- Batch 3/7 / Loss:  0.17824335
#    -- Batch 4/7 / Loss:  0.17956619
#    -- Batch 5/7 / Loss:  0.17559318
#    -- Batch 6/7 / Loss:  0.17744695
#    -- Batch 7/7 / Loss:  0.1813207
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.17827342}
#    Validation: {'f1': 0.9761011600494385, 'loss': 0.19148500263690948}
#    Saving to: epoch_68_model.ckpt
# Epoch 69/100
#    -- Batch 1/7 / Loss:  0.17626937
#    -- Batch 2/7 / Loss:  0.17768498
#    -- Batch 3/7 / Loss:  0.17891192
#    -- Batch 4/7 / Loss:  0.17561296
#    -- Batch 5/7 / Loss:  0.1781155
#    -- Batch 6/7 / Loss:  0.17287005
#    -- Batch 7/7 / Loss:  0.17641641
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.17655444}
#    Validation: {'f1': 0.9760943651199341, 'loss': 0.18945252895355225}
#    Saving to: epoch_69_model.ckpt
# Epoch 70/100
#    -- Batch 1/7 / Loss:  0.17662887
#    -- Batch 2/7 / Loss:  0.17583099
#    -- Batch 3/7 / Loss:  0.17484261
#    -- Batch 4/7 / Loss:  0.1737857
#    -- Batch 5/7 / Loss:  0.17596349
#    -- Batch 6/7 / Loss:  0.17164627
#    -- Batch 7/7 / Loss:  0.17335278
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.17457867}
#    Validation: {'f1': 0.9752110242843628, 'loss': 0.18801772594451904}
#    Saving to: epoch_70_model.ckpt
# Epoch 71/100
#    -- Batch 1/7 / Loss:  0.17397544
#    -- Batch 2/7 / Loss:  0.17139208
#    -- Batch 3/7 / Loss:  0.1753763
#    -- Batch 4/7 / Loss:  0.17333524
#    -- Batch 5/7 / Loss:  0.1705619
#    -- Batch 6/7 / Loss:  0.17452879
#    -- Batch 7/7 / Loss:  0.17104526
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.17288788}
#    Validation: {'f1': 0.9760816693305969, 'loss': 0.18649451434612274}
#    Saving to: epoch_71_model.ckpt
# Epoch 72/100
#    -- Batch 1/7 / Loss:  0.1694014
#    -- Batch 2/7 / Loss:  0.1777535
#    -- Batch 3/7 / Loss:  0.16986592
#    -- Batch 4/7 / Loss:  0.1705517
#    -- Batch 5/7 / Loss:  0.16815113
#    -- Batch 6/7 / Loss:  0.16922931
#    -- Batch 7/7 / Loss:  0.17337197
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.17118928}
#    Validation: {'f1': 0.9767916202545166, 'loss': 0.1838868111371994}
#    Saving to: epoch_72_model.ckpt
# Epoch 73/100
#    -- Batch 1/7 / Loss:  0.17091714
#    -- Batch 2/7 / Loss:  0.1673295
#    -- Batch 3/7 / Loss:  0.16964564
#    -- Batch 4/7 / Loss:  0.16687748
#    -- Batch 5/7 / Loss:  0.1702728
#    -- Batch 6/7 / Loss:  0.173371
#    -- Batch 7/7 / Loss:  0.16736327
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.16939668}
#    Validation: {'f1': 0.9763381481170654, 'loss': 0.18313078582286835}
#    Saving to: epoch_73_model.ckpt
# Epoch 74/100
#    -- Batch 1/7 / Loss:  0.16567954
#    -- Batch 2/7 / Loss:  0.16828203
#    -- Batch 3/7 / Loss:  0.16707295
#    -- Batch 4/7 / Loss:  0.16940154
#    -- Batch 5/7 / Loss:  0.16859867
#    -- Batch 6/7 / Loss:  0.16837433
#    -- Batch 7/7 / Loss:  0.16471949
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.16744693}
#    Validation: {'f1': 0.9761581420898438, 'loss': 0.181998148560524}
#    Saving to: epoch_74_model.ckpt
# Epoch 75/100
#    -- Batch 1/7 / Loss:  0.1670095
#    -- Batch 2/7 / Loss:  0.16790657
#    -- Batch 3/7 / Loss:  0.17232093
#    -- Batch 4/7 / Loss:  0.16581205
#    -- Batch 5/7 / Loss:  0.16273761
#    -- Batch 6/7 / Loss:  0.16460216
#    -- Batch 7/7 / Loss:  0.16298923
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.16619685}
#    Validation: {'f1': 0.975997269153595, 'loss': 0.18050415813922882}
#    Saving to: epoch_75_model.ckpt
# Epoch 76/100
#    -- Batch 1/7 / Loss:  0.16438642
#    -- Batch 2/7 / Loss:  0.1648142
#    -- Batch 3/7 / Loss:  0.16732824
#    -- Batch 4/7 / Loss:  0.16616017
#    -- Batch 5/7 / Loss:  0.16824888
#    -- Batch 6/7 / Loss:  0.1645106
#    -- Batch 7/7 / Loss:  0.16201508
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.16535194}
#    Validation: {'f1': 0.9740312099456787, 'loss': 0.18080802261829376}
#    Saving to: epoch_76_model.ckpt
# Epoch 77/100
#    -- Batch 1/7 / Loss:  0.16431563
#    -- Batch 2/7 / Loss:  0.16465758
#    -- Batch 3/7 / Loss:  0.16084827
#    -- Batch 4/7 / Loss:  0.1647513
#    -- Batch 5/7 / Loss:  0.16159916
#    -- Batch 6/7 / Loss:  0.167611
#    -- Batch 7/7 / Loss:  0.16480687
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.16408427}
#    Validation: {'f1': 0.9746490716934204, 'loss': 0.18019497394561768}
#    Saving to: epoch_77_model.ckpt
# Epoch 78/100
#    -- Batch 1/7 / Loss:  0.16337103
#    -- Batch 2/7 / Loss:  0.16153343
#    -- Batch 3/7 / Loss:  0.16442004
#    -- Batch 4/7 / Loss:  0.16687179
#    -- Batch 5/7 / Loss:  0.15837501
#    -- Batch 6/7 / Loss:  0.1589334
#    -- Batch 7/7 / Loss:  0.16419514
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.16252854}
#    Validation: {'f1': 0.9750564098358154, 'loss': 0.1770782321691513}
#    Saving to: epoch_78_model.ckpt
# Epoch 79/100
#    -- Batch 1/7 / Loss:  0.16132392
#    -- Batch 2/7 / Loss:  0.16038075
#    -- Batch 3/7 / Loss:  0.1585498
#    -- Batch 4/7 / Loss:  0.16146652
#    -- Batch 5/7 / Loss:  0.16146433
#    -- Batch 6/7 / Loss:  0.15769283
#    -- Batch 7/7 / Loss:  0.16087885
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.160251}
#    Validation: {'f1': 0.9766050577163696, 'loss': 0.17404228448867798}
#    Saving to: epoch_79_model.ckpt
# Epoch 80/100
#    -- Batch 1/7 / Loss:  0.1602509
#    -- Batch 2/7 / Loss:  0.15549198
#    -- Batch 3/7 / Loss:  0.1557914
#    -- Batch 4/7 / Loss:  0.16314957
#    -- Batch 5/7 / Loss:  0.1577547
#    -- Batch 6/7 / Loss:  0.15533753
#    -- Batch 7/7 / Loss:  0.16045472
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.15831868}
#    Validation: {'f1': 0.9758651256561279, 'loss': 0.17395079135894775}
#    Saving to: epoch_80_model.ckpt
# Epoch 81/100
#    -- Batch 1/7 / Loss:  0.16055727
#    -- Batch 2/7 / Loss:  0.15456249
#    -- Batch 3/7 / Loss:  0.15877807
#    -- Batch 4/7 / Loss:  0.15484059
#    -- Batch 5/7 / Loss:  0.15816309
#    -- Batch 6/7 / Loss:  0.1543788
#    -- Batch 7/7 / Loss:  0.15905751
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.15719111}
#    Validation: {'f1': 0.9763977527618408, 'loss': 0.1715768724679947}
#    Saving to: epoch_81_model.ckpt
# Epoch 82/100
#    -- Batch 1/7 / Loss:  0.15440965
#    -- Batch 2/7 / Loss:  0.15319926
#    -- Batch 3/7 / Loss:  0.1589649
#    -- Batch 4/7 / Loss:  0.15594861
#    -- Batch 5/7 / Loss:  0.15327689
#    -- Batch 6/7 / Loss:  0.15465446
#    -- Batch 7/7 / Loss:  0.15263681
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.15472722}
#    Validation: {'f1': 0.976457953453064, 'loss': 0.17046523094177246}
#    Saving to: epoch_82_model.ckpt
# Epoch 83/100
#    -- Batch 1/7 / Loss:  0.15221111
#    -- Batch 2/7 / Loss:  0.15420172
#    -- Batch 3/7 / Loss:  0.15204853
#    -- Batch 4/7 / Loss:  0.1547856
#    -- Batch 5/7 / Loss:  0.15203924
#    -- Batch 6/7 / Loss:  0.1541277
#    -- Batch 7/7 / Loss:  0.15072444
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.1528769}
#    Validation: {'f1': 0.9766364097595215, 'loss': 0.16880421340465546}
#    Saving to: epoch_83_model.ckpt
# Epoch 84/100
#    -- Batch 1/7 / Loss:  0.1539791
#    -- Batch 2/7 / Loss:  0.1519135
#    -- Batch 3/7 / Loss:  0.15126787
#    -- Batch 4/7 / Loss:  0.14905992
#    -- Batch 5/7 / Loss:  0.1509203
#    -- Batch 6/7 / Loss:  0.1522016
#    -- Batch 7/7 / Loss:  0.15199603
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.15161976}
#    Validation: {'f1': 0.9764344692230225, 'loss': 0.16833961009979248}
#    Saving to: epoch_84_model.ckpt
# Epoch 85/100
#    -- Batch 1/7 / Loss:  0.14986083
#    -- Batch 2/7 / Loss:  0.15270767
#    -- Batch 3/7 / Loss:  0.1511532
#    -- Batch 4/7 / Loss:  0.14910613
#    -- Batch 5/7 / Loss:  0.15033892
#    -- Batch 6/7 / Loss:  0.14971487
#    -- Batch 7/7 / Loss:  0.14811406
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.15014224}
#    Validation: {'f1': 0.9764759540557861, 'loss': 0.16660341620445251}
#    Saving to: epoch_85_model.ckpt
# Epoch 86/100
#    -- Batch 1/7 / Loss:  0.15430897
#    -- Batch 2/7 / Loss:  0.15002038
#    -- Batch 3/7 / Loss:  0.15142901
#    -- Batch 4/7 / Loss:  0.14818656
#    -- Batch 5/7 / Loss:  0.14977925
#    -- Batch 6/7 / Loss:  0.14534238
#    -- Batch 7/7 / Loss:  0.1516287
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.15009932}
#    Validation: {'f1': 0.9763473868370056, 'loss': 0.16486309468746185}
#    Saving to: epoch_86_model.ckpt
# Epoch 87/100
#    -- Batch 1/7 / Loss:  0.14865826
#    -- Batch 2/7 / Loss:  0.14740677
#    -- Batch 3/7 / Loss:  0.14779195
#    -- Batch 4/7 / Loss:  0.14931996
#    -- Batch 5/7 / Loss:  0.1468493
#    -- Batch 6/7 / Loss:  0.14808345
#    -- Batch 7/7 / Loss:  0.1446953
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.14754356}
#    Validation: {'f1': 0.9763044118881226, 'loss': 0.1640797108411789}
#    Saving to: epoch_87_model.ckpt
# Epoch 88/100
#    -- Batch 1/7 / Loss:  0.14837103
#    -- Batch 2/7 / Loss:  0.14577332
#    -- Batch 3/7 / Loss:  0.14387311
#    -- Batch 4/7 / Loss:  0.1463142
#    -- Batch 5/7 / Loss:  0.14362791
#    -- Batch 6/7 / Loss:  0.1513588
#    -- Batch 7/7 / Loss:  0.14330685
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.14608932}
#    Validation: {'f1': 0.9767131805419922, 'loss': 0.1629008650779724}
#    Saving to: epoch_88_model.ckpt
# Epoch 89/100
#    -- Batch 1/7 / Loss:  0.14487772
#    -- Batch 2/7 / Loss:  0.14504
#    -- Batch 3/7 / Loss:  0.14676508
#    -- Batch 4/7 / Loss:  0.14390343
#    -- Batch 5/7 / Loss:  0.14163682
#    -- Batch 6/7 / Loss:  0.14813258
#    -- Batch 7/7 / Loss:  0.14235914
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.14467354}
#    Validation: {'f1': 0.9763718843460083, 'loss': 0.1614094078540802}
#    Saving to: epoch_89_model.ckpt
# Epoch 90/100
#    -- Batch 1/7 / Loss:  0.14456137
#    -- Batch 2/7 / Loss:  0.14339605
#    -- Batch 3/7 / Loss:  0.14223322
#    -- Batch 4/7 / Loss:  0.14173958
#    -- Batch 5/7 / Loss:  0.14508468
#    -- Batch 6/7 / Loss:  0.1432589
#    -- Batch 7/7 / Loss:  0.14069584
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.14299567}
#    Validation: {'f1': 0.975951075553894, 'loss': 0.1608908623456955}
#    Saving to: epoch_90_model.ckpt
# Epoch 91/100
#    -- Batch 1/7 / Loss:  0.14150362
#    -- Batch 2/7 / Loss:  0.13927704
#    -- Batch 3/7 / Loss:  0.1398524
#    -- Batch 4/7 / Loss:  0.13935399
#    -- Batch 5/7 / Loss:  0.14278774
#    -- Batch 6/7 / Loss:  0.15099221
#    -- Batch 7/7 / Loss:  0.13966087
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.14191827}
#    Validation: {'f1': 0.9755913615226746, 'loss': 0.16124825179576874}
#    Saving to: epoch_91_model.ckpt
# Epoch 92/100
#    -- Batch 1/7 / Loss:  0.1439376
#    -- Batch 2/7 / Loss:  0.14124998
#    -- Batch 3/7 / Loss:  0.1406664
#    -- Batch 4/7 / Loss:  0.14208487
#    -- Batch 5/7 / Loss:  0.13850419
#    -- Batch 6/7 / Loss:  0.13740848
#    -- Batch 7/7 / Loss:  0.14175189
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.14080049}
#    Validation: {'f1': 0.9754811525344849, 'loss': 0.15936721861362457}
#    Saving to: epoch_92_model.ckpt
# Epoch 93/100
#    -- Batch 1/7 / Loss:  0.13915266
#    -- Batch 2/7 / Loss:  0.13942656
#    -- Batch 3/7 / Loss:  0.13920061
#    -- Batch 4/7 / Loss:  0.13920303
#    -- Batch 5/7 / Loss:  0.1377459
#    -- Batch 6/7 / Loss:  0.1401193
#    -- Batch 7/7 / Loss:  0.14022362
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.13929597}
#    Validation: {'f1': 0.9762177467346191, 'loss': 0.1573709100484848}
#    Saving to: epoch_93_model.ckpt
# Epoch 94/100
#    -- Batch 1/7 / Loss:  0.13822973
#    -- Batch 2/7 / Loss:  0.13789082
#    -- Batch 3/7 / Loss:  0.13739386
#    -- Batch 4/7 / Loss:  0.13717715
#    -- Batch 5/7 / Loss:  0.13826896
#    -- Batch 6/7 / Loss:  0.1348662
#    -- Batch 7/7 / Loss:  0.14279123
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.13808827}
#    Validation: {'f1': 0.9759741425514221, 'loss': 0.15718214213848114}
#    Saving to: epoch_94_model.ckpt
# Epoch 95/100
#    -- Batch 1/7 / Loss:  0.13688046
#    -- Batch 2/7 / Loss:  0.13613243
#    -- Batch 3/7 / Loss:  0.1351324
#    -- Batch 4/7 / Loss:  0.14150164
#    -- Batch 5/7 / Loss:  0.13675745
#    -- Batch 6/7 / Loss:  0.13633168
#    -- Batch 7/7 / Loss:  0.13730781
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.13714913}
#    Validation: {'f1': 0.9758991003036499, 'loss': 0.15576522052288055}
#    Saving to: epoch_95_model.ckpt
# Epoch 96/100
#    -- Batch 1/7 / Loss:  0.13786848
#    -- Batch 2/7 / Loss:  0.13843104
#    -- Batch 3/7 / Loss:  0.13685763
#    -- Batch 4/7 / Loss:  0.1348389
#    -- Batch 5/7 / Loss:  0.13314728
#    -- Batch 6/7 / Loss:  0.13292116
#    -- Batch 7/7 / Loss:  0.13308786
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.13530748}
#    Validation: {'f1': 0.9769665002822876, 'loss': 0.15321658551692963}
#    Saving to: epoch_96_model.ckpt
# Epoch 97/100
#    -- Batch 1/7 / Loss:  0.13832083
#    -- Batch 2/7 / Loss:  0.13158791
#    -- Batch 3/7 / Loss:  0.13655162
#    -- Batch 4/7 / Loss:  0.13266076
#    -- Batch 5/7 / Loss:  0.1349264
#    -- Batch 6/7 / Loss:  0.13269189
#    -- Batch 7/7 / Loss:  0.13276957
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.13421556}
#    Validation: {'f1': 0.9761539697647095, 'loss': 0.15323129296302795}
#    Saving to: epoch_97_model.ckpt
# Epoch 98/100
#    -- Batch 1/7 / Loss:  0.1320953
#    -- Batch 2/7 / Loss:  0.13709508
#    -- Batch 3/7 / Loss:  0.13296597
#    -- Batch 4/7 / Loss:  0.13325731
#    -- Batch 5/7 / Loss:  0.13435064
#    -- Batch 6/7 / Loss:  0.1302617
#    -- Batch 7/7 / Loss:  0.13211668
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.13316324}
#    Validation: {'f1': 0.9757492542266846, 'loss': 0.1525546759366989}
#    Saving to: epoch_98_model.ckpt
# Epoch 99/100
#    -- Batch 1/7 / Loss:  0.1324478
#    -- Batch 2/7 / Loss:  0.1328789
#    -- Batch 3/7 / Loss:  0.13044326
#    -- Batch 4/7 / Loss:  0.13030648
#    -- Batch 5/7 / Loss:  0.13251746
#    -- Batch 6/7 / Loss:  0.13180909
#    -- Batch 7/7 / Loss:  0.13305593
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.1319227}
#    Validation: {'f1': 0.9762829542160034, 'loss': 0.15119889378547668}
#    Saving to: epoch_99_model.ckpt
# Epoch 100/100
#    -- Batch 1/7 / Loss:  0.12970407
#    -- Batch 2/7 / Loss:  0.1306087
#    -- Batch 3/7 / Loss:  0.12749599
#    -- Batch 4/7 / Loss:  0.13198012
#    -- Batch 5/7 / Loss:  0.1333711
#    -- Batch 6/7 / Loss:  0.13132423
#    -- Batch 7/7 / Loss:  0.13059215
#    Validation running...
#    Mean epoch metrics:
#    Training:   {'loss': 0.13072519}
#    Validation: {'f1': 0.9756921529769897, 'loss': 0.1511370688676834}
#    Saving to: epoch_100_model.ckpt

# %% [markdown]
# ## Plot training and validation histories

# %%
plot_histories(train_history['loss'], val_history['loss'], label="Loss")
plot_histories(train_history=None, val_history=val_history['f1'], label="F1 Score")
plt.show()

# %% [markdown]
# ## Evaluate on single test-set image

# %%
# Predict on a test image
x_test, y_test = test_dataset[0]
if gpu:
  x_test = x_test.to(device)
  y_test = y_test.to(device)
pred = model(x_test.view(1, 1, x_test.shape[1], x_test.shape[2])).argmax(1).cpu().numpy()

# Plot the result
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(15, 15))
ax1.set_title("True mask")
ax2.set_title("Predicted mask")

plot_image_with_segmentation(x_test.cpu(), y_test.cpu(), ax=ax1)
plot_image_with_segmentation(x_test.cpu(), pred, ax=ax2)

plt.show()

# %% [markdown]
# ## Evaluate on whole test-set

# %%
# OBS: Returns batch-wise metrics, but test_loader has batch_size = 1
f1_test_scores = evaluate_model(model, test_loader, metrics, reduction=False)["f1"]

print("Test cases:", len(f1_test_scores))
print("Mean F1:   ", np.mean(f1_test_scores))
print("STD  F1:   ", np.std(f1_test_scores))
print("Min. F1:   ", np.min(f1_test_scores))
# Out:
# Test cases: 123
# Mean F1:    0.9735601980511736
# STD  F1:    0.015204254970561049
# Min. F1:    0.9133150577545166
